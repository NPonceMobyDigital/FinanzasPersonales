-- %% [markdown]
-- # [FinanzasPersonales]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [FinanzasPersonales]    Script Date: 22/12/2022 8:27:30 ******/
CREATE DATABASE [FinanzasPersonales]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'FinanzasPersonales', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\FinanzasPersonales.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'FinanzasPersonales_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL15.SQLEXPRESS\MSSQL\DATA\FinanzasPersonales_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
 WITH CATALOG_COLLATION = DATABASE_DEFAULT
GO
ALTER DATABASE [FinanzasPersonales] SET COMPATIBILITY_LEVEL = 150
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [FinanzasPersonales].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [FinanzasPersonales] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [FinanzasPersonales] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [FinanzasPersonales] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [FinanzasPersonales] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [FinanzasPersonales] SET ARITHABORT OFF 
GO
ALTER DATABASE [FinanzasPersonales] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [FinanzasPersonales] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [FinanzasPersonales] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [FinanzasPersonales] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [FinanzasPersonales] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [FinanzasPersonales] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [FinanzasPersonales] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [FinanzasPersonales] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [FinanzasPersonales] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [FinanzasPersonales] SET  DISABLE_BROKER 
GO
ALTER DATABASE [FinanzasPersonales] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [FinanzasPersonales] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [FinanzasPersonales] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [FinanzasPersonales] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [FinanzasPersonales] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [FinanzasPersonales] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [FinanzasPersonales] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [FinanzasPersonales] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [FinanzasPersonales] SET  MULTI_USER 
GO
ALTER DATABASE [FinanzasPersonales] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [FinanzasPersonales] SET DB_CHAINING OFF 
GO
ALTER DATABASE [FinanzasPersonales] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [FinanzasPersonales] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [FinanzasPersonales] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [FinanzasPersonales] SET ACCELERATED_DATABASE_RECOVERY = OFF  
GO
ALTER DATABASE [FinanzasPersonales] SET QUERY_STORE = OFF
GO

-- %% [markdown]
-- # [dbo].[Saldos]

-- %%
USE [FinanzasPersonales]
GO

-- %%
/****** Object:  Table [dbo].[Saldos]    Script Date: 22/12/2022 8:27:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Saldos](
	[ID_Saldo] [int] IDENTITY(1,1) NOT NULL,
	[Monto] [int] NOT NULL,
	[FechaAlta] [datetime] NOT NULL,
	[FechaBaja] [datetime] NULL,
 CONSTRAINT [PK_SALDOS] PRIMARY KEY CLUSTERED 
(
	[ID_Saldo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Ingresos]

-- %%
/****** Object:  Table [dbo].[Ingresos]    Script Date: 22/12/2022 8:27:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Ingresos](
	[ID_Ingreso] [int] IDENTITY(1,1) NOT NULL,
	[Monto] [int] NOT NULL,
	[Detalle] [varchar](50) NOT NULL,
	[FechaAlta] [datetime] NOT NULL,
	[FechaBaja] [datetime] NULL,
 CONSTRAINT [PK_Ingresos] PRIMARY KEY CLUSTERED 
(
	[ID_Ingreso] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[IngresosFuturos]

-- %%
/****** Object:  Table [dbo].[IngresosFuturos]    Script Date: 22/12/2022 8:27:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[IngresosFuturos](
	[ID_IngresosFuturos] [int] IDENTITY(1,1) NOT NULL,
	[Monto] [int] NOT NULL,
	[Detalle] [varchar](50) NOT NULL,
	[FechaAlta] [datetime] NOT NULL,
	[FechaBaja] [datetime] NULL,
	[FechaEjecucion] [date] NOT NULL,
 CONSTRAINT [PK_INGRESOS_FUTUROS] PRIMARY KEY CLUSTERED 
(
	[ID_IngresosFuturos] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Egresos]

-- %%
/****** Object:  Table [dbo].[Egresos]    Script Date: 22/12/2022 8:27:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Egresos](
	[ID_Egreso] [int] IDENTITY(1,1) NOT NULL,
	[Monto] [int] NOT NULL,
	[Detalle] [varchar](50) NOT NULL,
	[FechaDeAlta] [datetime] NOT NULL,
	[FechaDeBaja] [datetime] NULL,
 CONSTRAINT [PK_Egresos] PRIMARY KEY CLUSTERED 
(
	[ID_Egreso] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[EgresosFuturos]

-- %%
/****** Object:  Table [dbo].[EgresosFuturos]    Script Date: 22/12/2022 8:27:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[EgresosFuturos](
	[Id_EgresosFuturos] [int] IDENTITY(1,1) NOT NULL,
	[Monto] [int] NOT NULL,
	[Detalle] [nvarchar](50) NOT NULL,
	[FechaAlta] [datetime] NOT NULL,
	[FechaBaja] [datetime] NULL,
	[FechaEjecucion] [date] NOT NULL,
 CONSTRAINT [PK_EgresosFuturos] PRIMARY KEY CLUSTERED 
(
	[Id_EgresosFuturos] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[SaldosFuturos]

-- %%
/****** Object:  Table [dbo].[SaldosFuturos]    Script Date: 22/12/2022 8:27:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[SaldosFuturos](
	[ID_MontoFuturo] [int] IDENTITY(1,1) NOT NULL,
	[Monto] [int] NOT NULL,
	[Descripcion] [varchar](50) NOT NULL,
	[FechaDeAlta] [datetime] NOT NULL,
	[FechaDeBaja] [datetime] NULL,
	[FechaDeConcrecion] [nchar](10) NOT NULL,
 CONSTRAINT [PK_SaldosFuturos] PRIMARY KEY CLUSTERED 
(
	[ID_MontoFuturo] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[Perfiles]

-- %%
/****** Object:  Table [dbo].[Perfiles]    Script Date: 22/12/2022 8:27:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[Perfiles](
	[ID_Perfil] [int] IDENTITY(1,1) NOT NULL,
	[Nombre] [varchar](50) NOT NULL,
	[ID_Saldo] [int] NULL,
	[ID_Ingreso] [int] NULL,
	[ID_IngresoFuturo] [int] NULL,
	[ID_Egreso] [int] NULL,
	[ID_EgresoFuturo] [int] NULL,
	[FechaAlta] [datetime] NOT NULL,
	[FechaBaja] [datetime] NULL,
	[ID_SaldoFuturo] [int] NULL,
	[Usuario] [varchar](50) NOT NULL,
	[Contraseña] [varchar](50) NOT NULL,
 CONSTRAINT [PK_Perfiles] PRIMARY KEY CLUSTERED 
(
	[ID_Perfil] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON, OPTIMIZE_FOR_SEQUENTIAL_KEY = OFF) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[VistaPerfiles]

-- %%
/****** Object:  View [dbo].[VistaPerfiles]    Script Date: 22/12/2022 8:27:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE VIEW [dbo].[VistaPerfiles]
AS
SELECT        dbo.Perfiles.ID_Saldo AS Saldo, dbo.Perfiles.ID_Ingreso AS Ingreso, dbo.Perfiles.ID_IngresoFuturo AS IngresoFuturo, dbo.Perfiles.ID_Egreso AS Egreso, dbo.Perfiles.ID_EgresoFuturo AS EgresoFuturo, 
                         dbo.Perfiles.ID_SaldoFuturo AS [Saldo Futuro], dbo.Perfiles.Nombre, dbo.Perfiles.Usuario
FROM            dbo.Egresos INNER JOIN
                         dbo.Perfiles ON dbo.Egresos.ID_Egreso = dbo.Perfiles.ID_Egreso INNER JOIN
                         dbo.EgresosFuturos ON dbo.Perfiles.ID_EgresoFuturo = dbo.EgresosFuturos.Id_EgresosFuturos INNER JOIN
                         dbo.Ingresos ON dbo.Perfiles.ID_Ingreso = dbo.Ingresos.ID_Ingreso INNER JOIN
                         dbo.IngresosFuturos ON dbo.Perfiles.ID_IngresoFuturo = dbo.IngresosFuturos.ID_IngresosFuturos INNER JOIN
                         dbo.Saldos ON dbo.Perfiles.ID_Saldo = dbo.Saldos.ID_Saldo INNER JOIN
                         dbo.SaldosFuturos ON dbo.Perfiles.ID_SaldoFuturo = dbo.SaldosFuturos.ID_MontoFuturo
GO

-- %% [markdown]
-- # [DF_Egresos_FechaDeAlta]

-- %%
ALTER TABLE [dbo].[Egresos] ADD  CONSTRAINT [DF_Egresos_FechaDeAlta]  DEFAULT (getdate()) FOR [FechaDeAlta]
GO

-- %% [markdown]
-- # [DF_EgresosFuturos_FechaAlta]

-- %%
ALTER TABLE [dbo].[EgresosFuturos] ADD  CONSTRAINT [DF_EgresosFuturos_FechaAlta]  DEFAULT (getdate()) FOR [FechaAlta]
GO

-- %% [markdown]
-- # [DF_Ingresos_FechaAlta]

-- %%
ALTER TABLE [dbo].[Ingresos] ADD  CONSTRAINT [DF_Ingresos_FechaAlta]  DEFAULT (getdate()) FOR [FechaAlta]
GO

-- %% [markdown]
-- # [DF_IngresosFuturos_FechaAlta]

-- %%
ALTER TABLE [dbo].[IngresosFuturos] ADD  CONSTRAINT [DF_IngresosFuturos_FechaAlta]  DEFAULT (getdate()) FOR [FechaAlta]
GO

-- %% [markdown]
-- # [DF_Perfiles_FechaAlta]

-- %%
ALTER TABLE [dbo].[Perfiles] ADD  CONSTRAINT [DF_Perfiles_FechaAlta]  DEFAULT (getdate()) FOR [FechaAlta]
GO

-- %% [markdown]
-- # [DF_Saldos_FechaAlta]

-- %%
ALTER TABLE [dbo].[Saldos] ADD  CONSTRAINT [DF_Saldos_FechaAlta]  DEFAULT (getdate()) FOR [FechaAlta]
GO

-- %% [markdown]
-- # [DF_SaldosFuturos_FechaDeAlta]

-- %%
ALTER TABLE [dbo].[SaldosFuturos] ADD  CONSTRAINT [DF_SaldosFuturos_FechaDeAlta]  DEFAULT (getdate()) FOR [FechaDeAlta]
GO

-- %% [markdown]
-- # [FK_Perfiles_Egresos]

-- %%
ALTER TABLE [dbo].[Perfiles]  WITH CHECK ADD  CONSTRAINT [FK_Perfiles_Egresos] FOREIGN KEY([ID_Egreso])
REFERENCES [dbo].[Egresos] ([ID_Egreso])
GO
ALTER TABLE [dbo].[Perfiles] CHECK CONSTRAINT [FK_Perfiles_Egresos]
GO

-- %% [markdown]
-- # [FK_Perfiles_EgresosFuturos]

-- %%
ALTER TABLE [dbo].[Perfiles]  WITH CHECK ADD  CONSTRAINT [FK_Perfiles_EgresosFuturos] FOREIGN KEY([ID_EgresoFuturo])
REFERENCES [dbo].[EgresosFuturos] ([Id_EgresosFuturos])
GO
ALTER TABLE [dbo].[Perfiles] CHECK CONSTRAINT [FK_Perfiles_EgresosFuturos]
GO

-- %% [markdown]
-- # [FK_Perfiles_Ingresos]

-- %%
ALTER TABLE [dbo].[Perfiles]  WITH CHECK ADD  CONSTRAINT [FK_Perfiles_Ingresos] FOREIGN KEY([ID_Ingreso])
REFERENCES [dbo].[Ingresos] ([ID_Ingreso])
GO
ALTER TABLE [dbo].[Perfiles] CHECK CONSTRAINT [FK_Perfiles_Ingresos]
GO

-- %% [markdown]
-- # [FK_Perfiles_IngresosFuturos]

-- %%
ALTER TABLE [dbo].[Perfiles]  WITH CHECK ADD  CONSTRAINT [FK_Perfiles_IngresosFuturos] FOREIGN KEY([ID_IngresoFuturo])
REFERENCES [dbo].[IngresosFuturos] ([ID_IngresosFuturos])
GO
ALTER TABLE [dbo].[Perfiles] CHECK CONSTRAINT [FK_Perfiles_IngresosFuturos]
GO

-- %% [markdown]
-- # [FK_Perfiles_Saldos]

-- %%
ALTER TABLE [dbo].[Perfiles]  WITH CHECK ADD  CONSTRAINT [FK_Perfiles_Saldos] FOREIGN KEY([ID_Saldo])
REFERENCES [dbo].[Saldos] ([ID_Saldo])
GO
ALTER TABLE [dbo].[Perfiles] CHECK CONSTRAINT [FK_Perfiles_Saldos]
GO

-- %% [markdown]
-- # [FK_Perfiles_SaldosFuturos]

-- %%
ALTER TABLE [dbo].[Perfiles]  WITH CHECK ADD  CONSTRAINT [FK_Perfiles_SaldosFuturos] FOREIGN KEY([ID_SaldoFuturo])
REFERENCES [dbo].[SaldosFuturos] ([ID_MontoFuturo])
GO
ALTER TABLE [dbo].[Perfiles] CHECK CONSTRAINT [FK_Perfiles_SaldosFuturos]
GO

-- %% [markdown]
-- # [MS_DiagramPane1]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPane1', @value=N'[0E232FF0-B466-11cf-A24F-00AA00A3EFFF, 1.00]
Begin DesignProperties = 
   Begin PaneConfigurations = 
      Begin PaneConfiguration = 0
         NumPanes = 4
         Configuration = "(H (1[40] 4[20] 2[20] 3) )"
      End
      Begin PaneConfiguration = 1
         NumPanes = 3
         Configuration = "(H (1 [50] 4 [25] 3))"
      End
      Begin PaneConfiguration = 2
         NumPanes = 3
         Configuration = "(H (1 [50] 2 [25] 3))"
      End
      Begin PaneConfiguration = 3
         NumPanes = 3
         Configuration = "(H (4 [30] 2 [40] 3))"
      End
      Begin PaneConfiguration = 4
         NumPanes = 2
         Configuration = "(H (1 [56] 3))"
      End
      Begin PaneConfiguration = 5
         NumPanes = 2
         Configuration = "(H (2 [66] 3))"
      End
      Begin PaneConfiguration = 6
         NumPanes = 2
         Configuration = "(H (4 [50] 3))"
      End
      Begin PaneConfiguration = 7
         NumPanes = 1
         Configuration = "(V (3))"
      End
      Begin PaneConfiguration = 8
         NumPanes = 3
         Configuration = "(H (1[56] 4[18] 2) )"
      End
      Begin PaneConfiguration = 9
         NumPanes = 2
         Configuration = "(H (1 [75] 4))"
      End
      Begin PaneConfiguration = 10
         NumPanes = 2
         Configuration = "(H (1[66] 2) )"
      End
      Begin PaneConfiguration = 11
         NumPanes = 2
         Configuration = "(H (4 [60] 2))"
      End
      Begin PaneConfiguration = 12
         NumPanes = 1
         Configuration = "(H (1) )"
      End
      Begin PaneConfiguration = 13
         NumPanes = 1
         Configuration = "(V (4))"
      End
      Begin PaneConfiguration = 14
         NumPanes = 1
         Configuration = "(V (2))"
      End
      ActivePaneConfig = 0
   End
   Begin DiagramPane = 
      Begin Origin = 
         Top = -96
         Left = 0
      End
      Begin Tables = 
         Begin Table = "Egresos"
            Begin Extent = 
               Top = 6
               Left = 38
               Bottom = 136
               Right = 208
            End
            DisplayFlags = 280
            TopColumn = 0
         End
         Begin Table = "Perfiles"
            Begin Extent = 
               Top = 138
               Left = 38
               Bottom = 268
               Right = 217
            End
            DisplayFlags = 280
            TopColumn = 8
         End
         Begin Table = "EgresosFuturos"
            Begin Extent = 
               Top = 6
               Left = 246
               Bottom = 136
               Right = 430
            End
            DisplayFlags = 280
            TopColumn = 0
         End
         Begin Table = "Ingresos"
            Begin Extent = 
               Top = 6
               Left = 468
               Bottom = 136
               Right = 638
            End
            DisplayFlags = 280
            TopColumn = 0
         End
         Begin Table = "IngresosFuturos"
            Begin Extent = 
               Top = 6
               Left = 676
               Bottom = 136
               Right = 865
            End
            DisplayFlags = 280
            TopColumn = 0
         End
         Begin Table = "Saldos"
            Begin Extent = 
               Top = 138
               Left = 255
               Bottom = 268
               Right = 425
            End
            DisplayFlags = 280
            TopColumn = 0
         End
         Begin Table = "SaldosFuturos"
            Begin Extent = 
               Top = 138
               Left = 463
               Bottom = 268
               Right = 658
            End
          ' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'VistaPerfiles'
GO

-- %% [markdown]
-- # [MS_DiagramPane2]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPane2', @value=N'  DisplayFlags = 280
            TopColumn = 0
         End
      End
   End
   Begin SQLPane = 
   End
   Begin DataPane = 
      Begin ParameterDefaults = ""
      End
   End
   Begin CriteriaPane = 
      Begin ColumnWidths = 11
         Column = 2565
         Alias = 1740
         Table = 1170
         Output = 1230
         Append = 1400
         NewValue = 1170
         SortType = 1350
         SortOrder = 1410
         GroupBy = 1350
         Filter = 1350
         Or = 1350
         Or = 1350
         Or = 1350
      End
   End
End
' , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'VistaPerfiles'
GO

-- %% [markdown]
-- # [MS_DiagramPaneCount]

-- %%
EXEC sys.sp_addextendedproperty @name=N'MS_DiagramPaneCount', @value=2 , @level0type=N'SCHEMA',@level0name=N'dbo', @level1type=N'VIEW',@level1name=N'VistaPerfiles'
GO

-- %% [markdown]
-- # [FinanzasPersonales]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [FinanzasPersonales] SET  READ_WRITE 
GO
